# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# Andiamo su http://www.datiopen.it/it/opendata/Mappa_dei_pub_circoli_locali_in_Italia e scarichiamo il file della mappa dei pub, circoli e locali in Italia.

# %%
# importiamo il file

pub = pd.read_csv('/content/drive/MyDrive/PYTHON/Mappa-dei-pub-circoli-locali-in-Italia.csv', encoding='latin-1', sep=';')
pub
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %% [markdown]
# Esaminiamo il dataset:
# * quanti dati ci sono in totale?
# * quali sono i metadati?
# * stampiamo il primo elemento
# * stampiamo l'ultimo elemento
# * riusciamo a stampare un elemento a caso?
# * quali sono gli anni di inserimento presenti?
# * quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?
# * quante attività ci sono nella provincia di Vicenza?
# * quante enoteche ci sono, e come si chiamano?

# %%
# quanti dati ci sono in totale?

print('Il dataset contiene', pub.shape[0], 'righe e', pub.shape[1], 'colonne.')
print('Il dataset contiene', pub.size, 'elementi.')
# Out:
# Il dataset contiene 2635 righe e 9 colonne.
# Il dataset contiene 23715 elementi.

# %%
# quali sono i metadati?

pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
# stampiamo il primo elemento

pub.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
# stampiamo l'ultimo elemento

pub.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
# riusciamo a stampare un elemento a caso?

pub.sample(1)
# Out:
#          Comune Provincia              Regione      Nome  Anno inserimento  \
# 833  VILLABASSA   BOLZANO  Trentino-Alto Adige  Freyhaus              2008
#
#     Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 833   2008-07-20T10:31:17Z                        279716572    12.169523
#
#      Latitudine
# 833   46.737893

# %%
# quali sono gli anni di inserimento presenti?

print('Gli anni di inserimento presenti sono: ')
for i in pub['Anno inserimento'].unique():
  print(" -",i)
# Out:
# Gli anni di inserimento presenti sono:
#  - 2011
#  - 2015
#  - 2010
#  - 2012
#  - 2014
#  - 2016
#  - 2013
#  - 2008
#  - 2009
#  - 2007

# %%
# quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?

print(f"Nel quadrato di longitudine 9-10 e latitudine 45-46 ci sono {pub[(pub['Longitudine'] >= 9) & (pub['Longitudine'] <= 10) & (pub['Latitudine'] >= 45) & (pub['Latitudine'] <= 46)].shape[0]} attività.")
# Out:
# Nel quadrato di longitudine 9-10 e latitudine 45-46 ci sono 306 attività.

# %%
# quante attività ci sono nella provincia di Vicenza?

provincia = input("Inserisci la provincia: ")
print(f"Nella provincia di {provincia} ci sono {pub[pub['Provincia'].str.contains(provincia, case=False, na=False)].shape[0]} attività.")
# Out:
# Inserisci la provincia: Vicenza
# Nella provincia di Vicenza ci sono 73 attività.

# %%
# quante enoteche ci sono, e come si chiamano?

print(f"Ci sono {pub[pub['Nome'].str.contains('enoteca', case=False, na=False)].shape[0]} enoteche. \n")
print("Le enoteche sono:")
for i in pub[pub['Nome'].str.contains('enoteca', case=False, na=False)]['Nome']:
  print(" -",i)
# Out:
# Ci sono 6 enoteche.
#
# Le enoteche sono:
#  - Enoteca con Cucina""Tirolin""
#  - Concordia Enoteca
#  - Enoteca Umberto
#  - Enoteca ""Al Brindisi""
#  - Enoteca ""da Massimo""
#  - Enoteca Il Violino Rosso

# %% [markdown]
# Il dataset insurance.csv contiene dati rispetto a caratteristiche e abitudini delle persone, e della zona in cui vivono, rispetto ai costi individuali per le cure mediche come premio per le assicurazioni sulla salute.
# * Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna
# * Quali sono le medie di charges rispetto a region? Ci sono differenze significative?
# * E rispetto a smoker? E a sex?
# * Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?

# %%
# importiamo il dataset

ins = pd.read_csv("/content/drive/MyDrive/PYTHON/beginner_datasets/insurance.csv")
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna

print(f"il dataset contiene {ins.shape[0]} righe e {ins.shape[1]} colonne")
print(f"il dataset contiene {ins.size} elementi")
print("---")
print("I nomi delle colonne sono:")
for i in ins.columns:
  print(" -", i)
print("---")
print("Questa è un anteprima del dataset: \n")
ins
# Out:
# il dataset contiene 1338 righe e 7 colonne
# il dataset contiene 9366 elementi
# ---
# I nomi delle colonne sono:
#  - age
#  - sex
#  - bmi
#  - children
#  - smoker
#  - region
#  - charges
# ---
# Questa è un anteprima del dataset:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# ...

# %%
# Quali sono le medie di charges rispetto a region? Ci sono differenze significative?

print("Le medie di charges rispetto a region sono: \n")
round(ins.groupby('region')['charges'].mean(), 2)
# Out:
# Le medie di charges rispetto a region sono:
# region
# northeast    13406.38
# northwest    12417.58
# southeast    14735.41
# southwest    12346.94
# Name: charges, dtype: float64

# %%
# E rispetto a smoker?

print("Le medie di charges rispetto a smoker sono: \n")
round(ins.groupby('smoker')['charges'].mean(), 2)
# Out:
# Le medie di charges rispetto a smoker sono:
# smoker
# no      8434.27
# yes    32050.23
# Name: charges, dtype: float64

# %%
# E a sex?

print("Le medie di charges rispetto a sex sono: \n")
round(ins.groupby('sex')['charges'].mean(), 2)
# Out:
# Le medie di charges rispetto a sex sono:
# sex
# female    12569.58
# male      13956.75
# Name: charges, dtype: float64

# %%
# Quali sono i descrittori statistici di bmi?

print("I descrittori statistici di bmi sono: \n")
ins.bmi.describe()
# Out:
# I descrittori statistici di bmi sono:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
# Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?

print("Il minimo, la media e il massimo di charges rispetto ai diversi quartili dei valori di bmi sono: \n")
ins.groupby(pd.qcut(ins['bmi'], 4, labels = ['Primo Quartile', 'Secondo Quartile', 'Terzo Quartile', 'Quarto Quartile']), observed = True)['charges'].agg(['min', 'mean', 'max'])
# Out:
# Il minimo, la media e il massimo di charges rispetto ai diversi quartili dei valori di bmi sono:
#                         min          mean          max
# bmi
# Primo Quartile    1121.8739  10360.662825  38245.59327
# Secondo Quartile  1131.5066  11407.831468  62592.87309
# Terzo Quartile    1135.9407  14358.173081  60021.39897
# Quarto Quartile   1141.4451  16987.936691  63770.42801

# %% [markdown]
# Carichiamo in un DataFrame il dataset iris.csv dei beginner_datasets e calcoliamo:
#
# * La media della lunghezza dei petali di tutto il dataset
# * La media della lunghezza dei petali per ogni specie di Iris, utilizzando il metodo .groupby()
# * Media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()

# %%
#importiamo il dataset

iris = pd.read_csv("/content/drive/MyDrive/PYTHON/beginner_datasets/iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Calcoliamo la media della lunghezza dei petali di tutto il dataset

print(f"La media della lunghezza dei petali di tutto il dataset è: {round(iris['petal_length'].mean(), 2)} cm")
# Out:
# La media della lunghezza dei petali di tutto il dataset è: 3.76 cm

# %%
# Calcoliamo la media della lunghezza dei petali per ogni specie di Iris, utilizzando il metodo .groupby()

print("La media della lunghezza dei petali per ogni specie di Iris è: \n")
round(iris.groupby('species')['petal_length'].mean(), 2)
# Out:
# La media della lunghezza dei petali per ogni specie di Iris è:
# species
# Iris-setosa        1.46
# Iris-versicolor    4.26
# Iris-virginica     5.55
# Name: petal_length, dtype: float64

# %%
#Calcoliamo media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()

print("La media, il minimo e il massimo della larghezza dei sepali per ogni specie sono: \n")
iris.groupby('species')['sepal_width'].agg(['mean', 'min', 'max'])
# Out:
# La media, il minimo e il massimo della larghezza dei sepali per ogni specie sono:
#                   mean  min  max
# species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %% [markdown]
# Nei beginner_datasets, il dataset wine.csv contiene delle analisi organolettiche su diverse qualità di vini:
# * Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale?
# * C'è differenza nella concentrazione alcolica per vini bianchi e vini rossi?
# * Rifacendo le analisi delle domande precedenti ma per il pH, cambia qualcosa?
# * E per i solfati?

# %%
#importiamo il dataset

wine = pd.read_csv("/content/drive/MyDrive/PYTHON/beginner_datasets/wine.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale?

print("La media di concentrazione alcolica del totale del dataset è: ", round(wine['alcohol'].mean(), 2))
print("---")
print("La media di concentrazione alcolica per ogni qualità è: \n")
round(wine.groupby('quality')['alcohol'].mean(), 2)
# Out:
# La media di concentrazione alcolica del totale del dataset è:  10.49
# ---
# La media di concentrazione alcolica per ogni qualità è:
# quality
# 3    10.22
# 4    10.18
# 5     9.84
# 6    10.59
# 7    11.39
# 8    11.68
# 9    12.18
# Name: alcohol, dtype: float64

# %%
# C'è differenza nella concentrazione alcolica per vini bianchi e vini rossi?

print("La media di concentrazione alcolica dei vini bianchi è: ", round(wine[wine['type'] == 'white']['alcohol'].mean(), 2))
print("La media di concentrazione alcolica dei vini rossi è: ", round(wine[wine['type'] == 'red']['alcohol'].mean(), 2))
# Out:
# La media di concentrazione alcolica dei vini bianchi è:  10.51
# La media di concentrazione alcolica dei vini rossi è:  10.42

# %%
# Rifacendo le analisi delle domande precedenti ma per il pH, cambia qualcosa?

print("La media del valore del pH del totale del dataset è: ", round(wine['pH'].mean(), 2))
print("---")
print("La media del valore del pH dei vini bianchi è: ", round(wine[wine['type'] == 'white']['pH'].mean(), 2))
print("La media del valore del pH dei vini rossi è: ", round(wine[wine['type'] == 'red']['pH'].mean(), 2))
print("---")
print("La media del valore del pH per ogni qualità è: \n")
round(wine.groupby('quality')['pH'].mean(), 2)
# Out:
# La media del valore del pH del totale del dataset è:  3.22
# ---
# La media del valore del pH dei vini bianchi è:  3.19
# La media del valore del pH dei vini rossi è:  3.31
# ---
# La media del valore del pH per ogni qualità è:
# quality
# 3    3.26
# 4    3.23
# 5    3.21
# 6    3.22
# 7    3.23
# 8    3.22
# 9    3.31
# Name: pH, dtype: float64

# %%
# E per i solfati?

print("La media del valore dei sulfati del totale del dataset è: ", round(wine['sulphates'].mean(), 2))
print("---")
print("La media del valore dei sulfati dei vini bianchi è: ", round(wine[wine['type'] == 'white']['sulphates'].mean(), 2))
print("La media del valore dei sulfati dei vini rossi è: ", round(wine[wine['type'] == 'red']['sulphates'].mean(), 2))
print("---")
print("La media del valore dei sulfati per ogni qualità è: \n")
round(wine.groupby('quality')['sulphates'].mean(), 2)
# Out:
# La media del valore dei sulfati del totale del dataset è:  0.53
# ---
# La media del valore dei sulfati dei vini bianchi è:  0.49
# La media del valore dei sulfati dei vini rossi è:  0.66
# ---
# La media del valore dei sulfati per ogni qualità è:
# quality
# 3    0.51
# 4    0.51
# 5    0.53
# 6    0.53
# 7    0.55
# 8    0.51
# 9    0.47
# Name: sulphates, dtype: float64

# %% [markdown]
# Nei beginner_datasets, il file boston.csv contiene il Boston Housing Dataset, che deriva dalle informazioni raccolte dal Census Service degli Stati Uniti sulle abitazioni nell'area di Boston. Di seguito vengono descritte le colonne del dataset:
# * CRIM - tasso di criminalità pro capite per città
# * ZN - proporzione di terreni residenziali suddivisi in zone per lotti superiori a 25.000 piedi quadrati.
# * INDUS - percentuale di acri di attività commerciali non al dettaglio per città.
# * CHAS - variabile dummy del fiume Charles (1 se il tratto costeggia il fiume; 0 altrimenti)
# * NOX - concentrazione di ossidi di azoto (parti per 10 milioni)
# * RM - numero medio di stanze per abitazione
# * AGE - proporzione di unità abitative occupate da proprietari costruite prima del 1940
# * DIS - distanze ponderate da cinque centri occupazionali di Boston
# * RAD - indice di accessibilità alle autostrade radiali
# * TAX - aliquota dell'imposta fondiaria sul valore pieno per 10.000 dollari
# * PTRATIO - rapporto alunni-insegnanti per città
# * BLACK - la percentuale di neri per città
# * LSTAT - % di popolazione di condizione più bassa
# * MEDV - Valore mediano delle case, espresso in migliaia di dollari

# %% [markdown]
# Esercizio:
# * La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?
# * Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato?
# * Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti? E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato?
# * Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? E del numero di stanze? E delle tasse?

# %%
# importiamo il dataset

bos = pd.read_csv("/content/drive/MyDrive/PYTHON/beginner_datasets/boston.csv")
bos
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?

print(f"La media del prezzo delle case che costeggiano il fiume è: {round((bos[bos['chas'] == 1]['medv'].mean() * 1000) , 2)} $")
print(f"La media del prezzo delle case che non costeggiano il fiume è: {round((bos[bos['chas'] == 0]['medv'].mean() * 1000) , 2)} $")

bos.groupby('chas')['medv'].mean()

# Osserviamo che le case costruite nelle zone che costeggiano il fiume hanno un valore medio più alto di più di 6000 $
# Out:
# La media del prezzo delle case che costeggiano il fiume è: 28440.0 $
# La media del prezzo delle case che non costeggiano il fiume è: 22093.84 $
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
# Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato?

bos.groupby(pd.qcut(bos['crim'], 3, labels = ['Basso tasso di criminalità', 'Medio tasso di criminalità', 'Alto tasso di criminalità']), observed = True)['medv'].mean() * 1000

# Osserviamo che il valore medio delle abitazioni è inversamente proporzionale al valore del tasso di criminalità.
# Ciò significa che nelle zone più sicure e con minor tasso di criminalità, il prezzo medio delle abitazioni aumenta.
# Out:
# crim
# Basso tasso di criminalità    26613.609467
# Medio tasso di criminalità    23358.928571
# Alto tasso di criminalità     17630.769231
# Name: medv, dtype: float64

# %%
# Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti?
print("La media del numero di stanze rispetto al rapporto alunni-insegnanti è: \n")
bos.groupby(pd.qcut(bos['ptratio'], 3, labels = ['Primo Terzile' , 'Secondo Terzile' , 'Terzo Terzile']), observed = True)['rm'].mean()

# Osserviamo che per bassi rapporti alunni-insegnanti (ovvero minor numero di studenti per insegnante), il numero delle stanze medio delle abitazioni è più alto.
# Per alti rapporti alunni-insegnanti (ovvero maggior numero di studenti per insegnante), il numero delle stanze medio delle abitazioni è più basso.
# Nelle zone con maggior numero di studenti per insegnante, le case hanno meno stanze quindi, presumibilmente, valgono di meno
# Out:
# La media del numero di stanze rispetto al rapporto alunni-insegnanti è:
# ptratio
# Primo Terzile      6.611649
# Secondo Terzile    6.122029
# Terzo Terzile      6.069964
# Name: rm, dtype: float64

# %%
# E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato?

print("La media del valore delle case rispetto al rapporto alunni-insegnanti è: \n")
bos.groupby(pd.qcut(bos['ptratio'], 3, labels = ['Primo Terzile' , 'Secondo Terzile' , 'Terzo Terzile']), observed = True)['medv'].mean()

# Confermiamo quanto ipotizzato, nell'analisi precedente, il valore medio delle case è minore nelle zone con maggior numero di studenti per insegnante.
# Out:
# La media del valore delle case rispetto al rapporto alunni-insegnanti è:
# ptratio
# Primo Terzile      28.227011
# Secondo Terzile    19.837681
# Terzo Terzile      18.123214
# Name: medv, dtype: float64

# %%
# Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni?

bos.groupby(pd.qcut(bos['rad'], 3), observed = True)['age'].mean()

# Osserviamo che per le zone con più alto indice di accessibilità alle autostrade radiali, la % delle abitazioni costruite prima del 1940 è più alta
# Out:
# rad
# (0.999, 4.0]    57.403125
# (4.0, 7.0]      64.600000
# (7.0, 24.0]     86.350641
# Name: age, dtype: float64

# %%
# E del numero di stanze?

bos.groupby(pd.qcut(bos['rad'], 3), observed = True)['rm'].mean()

# Osserviamo che per le zone con più alto indice di accessibilità alle autostrade radiali, il numero medio di stanze è lievemente inferiore rispetto alle zone con indice più basso.
# Out:
# rad
# (0.999, 4.0]    6.309031
# (4.0, 7.0]      6.373089
# (7.0, 24.0]     6.165019
# Name: rm, dtype: float64

# %%
# E delle tasse?

bos.groupby(pd.qcut(bos['rad'], 3), observed = True)['tax'].mean()

# Osserviamo che per le zone con più alto indice di accessibilità alle autostrade radiali, le tasse sono maggiori rispetto alle zone con indice più basso.
# Out:
# rad
# (0.999, 4.0]    304.135417
# (4.0, 7.0]      335.645570
# (7.0, 24.0]     609.884615
# Name: tax, dtype: float64

# %% [markdown]
# Abbiamo un DataFrame di dipendenti:
#
# employees_df = pd.DataFrame({'employee_id': [101, 102, 103, 104, 105], 'name': ['Alice', 'Bob','Charlie', 'David', 'Emma'], 'department_id': [1, 2, 1, 2, 3] })
#
# E un DataFrame di dipartimenti:
#
# departments_df = pd.DataFrame({ 'department_id': [1, 2, 3], 'department_name': ['HR', 'IT', 'Finance'], 'location': ['New York', 'San Francisco', 'Chicago'] })
#
# * Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti che sui dipartimenti, usando la funzione .merge()
# * Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente; poi unire i due dataset mediante il metodo .join()
# * Ci sono differenze nel risultato? Quali? Perché?

# %%
# creazione dei DataFrame

employees_df = pd.DataFrame({'employee_id': [101, 102, 103, 104, 105], 'name': ['Alice', 'Bob','Charlie', 'David', 'Emma'], 'department_id': [1, 2, 1, 2, 3] })
departments_df = pd.DataFrame({ 'department_id': [1, 2, 3], 'department_name': ['HR', 'IT', 'Finance'], 'location': ['New York', 'San Francisco', 'Chicago'] })

employees_df , departments_df
# Out:
# (   employee_id     name  department_id
#  0          101    Alice              1
#  1          102      Bob              2
#  2          103  Charlie              1
#  3          104    David              2
#  4          105     Emma              3,
#     department_id department_name       location
#  0              1              HR       New York
#  1              2              IT  San Francisco
#  2              3         Finance        Chicago)

# %%
# Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti che sui dipartimenti, usando la funzione .merge()

merge = employees_df.merge(departments_df, on = 'department_id')
merge
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %%
# Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente; poi unire i due dataset mediante il metodo .join()
# Ci sono differenze nel risultato? Quali? Perché?

employees_df.set_index('department_id', inplace = True)
departments_df.set_index('department_id', inplace = True)
employees_df.join(departments_df)
# Out:
#                employee_id     name department_name       location
# department_id
# 1                      101    Alice              HR       New York
# 2                      102      Bob              IT  San Francisco
# 1                      103  Charlie              HR       New York
# 2                      104    David              IT  San Francisco
# 3                      105     Emma         Finance        Chicago

# %% [markdown]
# Esercizio
# * Dal database AdventureWorksDW importiamo le tabelle dimemployee e dimemployeesalesterritory come DataFrame
# * Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey
# * Controlliamo la dimensione del DataFrame risultante: è quella attesa?
# * Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa e il DataFrame risultante della join precedente, usando le colonne SalesTerritoryKey
# * Su questo DataFrame contare quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region)
# * Valutiamo la media del BaseRate per ogni paese: ci sono differenze?

# %%
# %run Creazione_AdventureWorks.ipynb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.8 MB/s eta 0:00:00
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
query_de = "SELECT * FROM dimemployee"
de = pd.read_sql(query_de, db_engine)

query_dest = "SELECT * FROM dimemployeesalesterritory"
dest = pd.read_sql(query_dest, db_engine)

# %%
de
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
dest
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
# Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey

de_dest = de.merge(dest, on = 'EmployeeKey')
de_dest
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
# Controlliamo la dimensione del DataFrame risultante: è quella attesa?

print(f"Il numero di colonne atteso per il DataFrame risultante è: {de.shape[1] + dest.shape[1] - 1}")
print(f"Il numero di colonne effettivo del DataFrame risultante è: {de_dest.shape[1]}")
# Out:
# Il numero di colonne atteso per il DataFrame risultante è: 29
# Il numero di colonne effettivo del DataFrame risultante è: 29

# %%
# Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa e il DataFrame risultante della join precedente, usando le colonne SalesTerritoryKey

query_dst = "SELECT * FROM dimsalesterritory"
dst = pd.read_sql(query_dst, db_engine)

de_dest_dst = de_dest.merge(dst, on = 'SalesTerritoryKey')
de_dest_dst
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
de_dest_dst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 34 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   EmployeeKey                           39 non-null     int64
#  1   ParentEmployeeKey                     39 non-null     float64
#  2   EmployeeNationalIDAlternateKey        39 non-null     int64
#  3   ParentEmployeeNationalIDAlternateKey  39 non-null     float64
#  4   FirstName                             39 non-null     object
#  5   LastName                              39 non-null     object
#  6   MiddleName                            38 non-null     object
#  7   NameStyle                             39 non-null     int64
#  8   Title                                 39 non-null     object
#  9   HireDate                              39 non-null     object
#  10  BirthDate                             39 non-null     object
# ...

# %%
# Su questo DataFrame contare quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region)

de_dest_dst.groupby(['SalesTerritoryCountry', 'SalesTerritoryRegion'])['EmployeeKey'].count()
# Out:
# SalesTerritoryCountry  SalesTerritoryRegion
# Australia              Australia               3
# Canada                 Canada                  4
# France                 France                  4
# Germany                Germany                 3
# United Kingdom         United Kingdom          3
# United States          Central                 5
#                        Northeast               3
#                        Northwest               5
#                        Southeast               4
#                        Southwest               5
# Name: EmployeeKey, dtype: int64

# %%
# Valutiamo la media del BaseRate per ogni paese: ci sono differenze?

de_dest_dst.groupby('SalesTerritoryCountry')['BaseRate'].mean()
# Out:
# SalesTerritoryCountry
# Australia         47.764433
# Canada            41.592550
# France            41.592550
# Germany           47.764433
# United Kingdom    47.764433
# United States     39.909309
# Name: BaseRate, dtype: float64

# %%
de_dest_dst.BaseRate
# Out:
# 0     48.1010
# 1     48.1010
# 2     48.1010
# 3     48.1010
# 4     48.1010
# 5     48.1010
# 6     72.1154
# 7     72.1154
# 8     72.1154
# 9     72.1154
# 10    72.1154
# 11    72.1154
# 12    72.1154
# 13    72.1154
# 14    72.1154
# 15    72.1154
# 16    23.0769
# 17    23.0769
# 18    23.0769
# 19    23.0769
# 20    23.0769
# 21    23.0769
# 22    23.0769
# 23    23.0769
# 24    23.0769
# 25    23.0769
# 26    23.0769
# 27    23.0769
# 28    23.0769
# 29    48.1010
# 30    48.1010
# 31    48.1010
# 32    23.0769
# 33    23.0769
# 34    23.0769
# 35    23.0769
# 36    48.1010
# 37    23.0769
# 38    23.0769
# Name: BaseRate, dtype: float64
